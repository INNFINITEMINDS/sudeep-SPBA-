# %% [markdown]
# [1]
#
#
# # The below image is a screen shot of the Notebook  05ImageRendering where the clip  limit  has been changed to 0.06 to render the image.
#
#
# ![img.png](attachment:img.png)
# ![img2.png](attachment:img2.png)
#
#
# # The below image is a screen shot of the Notebook  05ImageRendering where the clip  limit  has been changed to 0.04 to render the image.
#
# ![img3.png](attachment:img3.png)
# ![img4.png](attachment:img4.png)

# %% [markdown]
# [2]
#
# syntax       : equalize_hist(image, nbins=256, mask=None)
#
# parameters   :
#                   1)image = array
#                     Image array.
#
#               2) nbins = int, (optional)
#                  Number of bins for image histogram.This argument is ignored for integer images, for which each integer                          is its own bin.
#
#               3) mask = ndarray of bools or 0s and 1s, (optional)
#                 Array of same shape as image.Only points at which mask == True are used for the equalization,which is applied                   to the whole image.
#
# It is a method that improves the contrast in an image, in order to stretch out the intensity range.

# %% [markdown]
# [3]
#
# syntax      :equalize_adapthist(image, kernel_size=None, clip_limit=0.01, nbins=256)
#
# parameters  :  1)image : (M, N[, C]) ndarray
#
#                  Input image.
#
#                2) kernel_size: integer or list-like,( optional)
#                    Defines the shape of contextual regions used in the algorithm.If iterable is passed, it must have the same                      number of elements as image.ndim(without color channel).If integer, it is broadcasted to each image                            dimension. By default, kernel_size is 1/8 of image height by 1/8 of its width.
#
#                3)clip_limit : float,(optional)
#                    Clipping limit, normalized between 0 and 1 (higher values give more contrast).
#
#                 4)nbins : int, (optional)
#                     Number of gray bins for histogram (“data range”).
#
#                  Returns:
#                     out : (M, N[, C]) ndarray
#                        Equalized image.
#
#
# An algorithm for local contrast enhancement, that uses histograms computed over different tile regions of the image. Local details can therefore be enhanced even in regions that are darker or lighter than most of the image.

# %% [markdown]
# [4]
#
# In a standard histogram equalization we use images's histogram to adjust the contrast of the output image but in adaptive histogram equalization we use clip_limit to change the overall contrast of the output image, i feel that adaptive histogram equalization is more useful to notice details of the output image.
